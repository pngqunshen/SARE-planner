# %%
from AREgym import AREEnv
import random
import os

# %%
env = AREEnv(500, 40, save_map=True)
env.reset()
print("world generation done")
for i in range(1):
    env.step(random.random())
# Out:
# world generation done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ab42b098075e> in <module>
#       3 print("world generation done")
#       4 for i in range(1000):
# ----> 5     env.step(random.random())
#
# ~/SARE-planner/AREgym.py in step(self, action)
#     119         for step in steps:
#     120             self.move(step[0], step[1])
# --> 121             self.get_laser_scan()
#     122
#     123             if self.save_map:
#
# ~/SARE-planner/AREgym.py in get_laser_scan(self)
#     158                 dy = int(math.sin(heading) * distance)
#     159                 if not utils.out_of_bounds(self.world.x + dx, \
# --> 160                                            self.world.y + dy, \
#     161                                             self.world.size):
#     162                     break
#
# KeyboardInterrupt:

# %%
img_path = "images"

if not os.path.exists(img_path):
    os.makedirs(img_path)

env.render(img_path)
